# %%
import pandas as pd
import nltk

# %%
def add_hate_keyword_count(hate_keywords_df, df):
    hate_keywords = hate_keywords_df.term.values
    hate_keyword_sources = hate_keywords_df.source.values
    

    def iterate_over_utterance(text, target_var):
        index = text
        
        sources = []
        words = []

        for i in range(0, len(hate_keywords)):
            hate_word = hate_keywords[i]
            source = hate_keyword_sources[i]
    
            if hate_word in nltk.word_tokenize(text):
                sources.append(source)
                words.append(hate_word)
                
        if target_var == 'count':
            return len(hate_word)
        elif target_var == 'source':
            return sources
        elif target_var == 'word':
            return hate_word
        elif target_var == 'count_unique':
            return len(set(hate_word))

    df['hate_keyword_count'] = df['utterance'].apply(iterate_over_utterance, target_var='count')
    df['hate_keyword_source'] = df['utterance'].apply(iterate_over_utterance, target_var='source')
    df['hate_keyword'] = df['utterance'].apply(iterate_over_utterance, target_var='word')
    df['hate_keyword_count_unique'] = df['utterance'].apply(iterate_over_utterance, target_var='count_unique')
    
    return df

# %%
hate_keywords_df = pd.read_csv('data/all_hate_keywords.csv', index_col=0)
hate_keywords_twitter = pd.read_csv('data/hate_keys_twitter.csv', header=None)
hate_keywords_twitter = hate_keywords_twitter.rename(columns={0:'term'})
hate_keywords_twitter['source'] = 'twitter'
hate_keywords_df = hate_keywords_df.append(hate_keywords_twitter)

# %%
df_test=pd.read_csv("results.csv")

# %%
def replace_val(df_categ):
    df_categ = df_categ.replace('neither',0)
    df_categ = df_categ.replace('not hate speech',0)
    df_categ = df_categ.replace('offensive language',1)
    df_categ = df_categ.replace('hate speech',2)
    return df_categ

df_test['we_label_fox_news'] = replace_val(df_test['we_label_fox_news'])
df_test['we_label_twitter'] = replace_val(df_test['we_label_twitter'])
df_test['bert_label_twitter'] = replace_val(df_test['bert_label_twitter'])
df_test['bert_label_fox_news'] = replace_val(df_test['bert_label_fox_news'])
df_test['lstm_label_twitter'] = replace_val(df_test['lstm_label_twitter'])
df_test['lstm_label_fox_news'] = replace_val(df_test['lstm_label_fox_news'])

# %%
df_test.head(2)
# Out:
#    Unnamed: 0    movie_name  index                            utterance  \
# 0           0  12 Angry Men      0            Thank you very much, sir.
# 1           1  12 Angry Men      1  You did a wonderful job. Wonderful.
#
#    count_utterances     tag  we_label_fox_news  we_label_twitter  \
# 0              2065  racism                  0                 0
# 1              2065  racism                  0                 0
#
#    bert_label_twitter  bert_label_fox_news  lstm_label_twitter  \
# 0                   0                    0                   2
# 1                   0                    0                   1
#
#    lstm_label_fox_news  hate_keyword_count  hate_keyword_count_unique  \
# 0                    0                   0                          0
# 1                    0                   0                          0
#
#   hate_keyword hate_keyword_sources
# 0           []                   []
# 1           []                   []

# %%
df_test['combined_results'] = df_test['we_label_fox_news']+df_test['we_label_twitter']+df_test['bert_label_twitter']+df_test['bert_label_fox_news']+df_test['lstm_label_twitter']+df_test['lstm_label_fox_news']

# %%
df_test.head(1)
# Out:
#    Unnamed: 0    movie_name  index                  utterance  \
# 0           0  12 Angry Men      0  Thank you very much, sir.
#
#    count_utterances     tag  we_label_fox_news  we_label_twitter  \
# 0              2065  racism                  0                 0
#
#    bert_label_twitter  bert_label_fox_news  lstm_label_twitter  \
# 0                   0                    0                   2
#
#    lstm_label_fox_news  hate_keyword_count  hate_keyword_count_unique  \
# 0                    0                   0                          0
#
#   hate_keyword hate_keyword_sources  combined_results
# 0           []                   []                 2

# %%
df_test['combined_normlized'] = round(df_test['combined_results']/df_test['combined_results'].max(),2)

# %%
def myFunc(count):
    if count == 1:
        return 1
    elif count == 2:
        return 2
    elif count==0:
        return 0
    else:
        return 3
df_test['keyword_count_formular'] = df_test['hate_keyword_count_unique'].apply(myFunc)

# %%
df_test['combined_results'] = df_test['combined_results']+df_test['keyword_count_formular']
df_test['combined_normlized'] = round(df_test['combined_results']/df_test['combined_results'].max(),2)

# %%
df_test.head(2)
# Out:
#    Unnamed: 0    movie_name  index                            utterance  \
# 0           0  12 Angry Men      0            Thank you very much, sir.
# 1           1  12 Angry Men      1  You did a wonderful job. Wonderful.
#
#    count_utterances     tag  we_label_fox_news  we_label_twitter  \
# 0              2065  racism                  0                 0
# 1              2065  racism                  0                 0
#
#    bert_label_twitter  bert_label_fox_news  lstm_label_twitter  \
# 0                   0                    0                   2
# 1                   0                    0                   1
#
#    lstm_label_fox_news  hate_keyword_count  hate_keyword_count_unique  \
# 0                    0                   0                          0
# 1                    0                   0                          0
#
#   hate_keyword hate_keyword_sources  combined_results  combined_normlized  \
# ...

# %%
df_test[(df_test['combined_normlized']>0.70) & (df_test['combined_normlized']<0.80)].head(20)
# Out:
#        Unnamed: 0          movie_name  index  \
# 3999         3999        A Bronx Tale    646
# 4294         4294        A Bronx Tale    941
# 4343         4343        A Bronx Tale    990
# 4495         4495        A Bronx Tale   1142
# 4548         4548        A Bronx Tale   1195
# 4785         4785        A Bronx Tale   1432
# 5063         5063        A Bronx Tale   1710
# 5179         5179        A Bronx Tale   1826
# 5689         5689      A Time to Kill    375
# 6573         6573      A Time to Kill   1259
# 8691         8691  American History X    411
# 8739         8739  American History X    459
# 8848         8848  American History X    568
# 8914         8914  American History X    634
# 8999         8999  American History X    719
# 9658         9658  American History X   1378
# 9832         9832  American History X   1552
# 9878         9878  American History X   1598
# 10008       10008  American History X   1728
# 10098       10098  American History X   1818
#
# ...

# %%
df_test.to_csv("combined_results.csv")

# %%
# df_test[df_test['combined_normlized']>0.90]
# df_test_good = df_test[df_test['combined_normlized']>0.80]
for utterance,hate_keyw in enumerate(df_test[(df_test['combined_normlized']>0.60) & (df_test['combined_normlized']<0.70)][['utterance','hate_keyword','Unnamed: 0']].values):
    print(utterance)
    print(hate_keyw)
    print('---')
# df_test_good.describe()
# Out:
# 0
# ['He was born in a slum.' '[]' 487]
# ---
# 1
# ['"I\'m gonna kill you," body hitting the floor a split second later...'
#  "['kill']" 971]
# ---
# 2
# ['He said he yelled at the top of his voice.' '[]' 977]
# ---
# 3
# ['You ought to write for one of those kooky detective magazines.' '[]'
#  1070]
# ---
# 4
# [' Fifteen seconds after the body hit the floor.' '[]' 1282]
# ---
# 5
# ['A real  He was an ox.' '[]' 1501]
# ---
# 6
# ['Will you move your ass?' "['ass']" 2086]
# ---
# 7
# ['.350Caliber jobs, Probably handle about...' '[]' 2215]
# ---
# 8
# ['Ooh, these are marvelous doughnuts.' '[]' 2371]
# ---
# 9
# ['I take it black.' "['black']" 2378]
# ---
# 10
# ["I'll take it black." "['black']" 2401]
# ---
# 11
# ['I think a voice is like an instrument.' '[]' 2426]
# ---
# 12
# ['Stop it.' '[]' 2613]
# ---
# 13
# ['An arm? No, it felt like a breast.' '[]' 2689]
# ---
# 14
# ['Go on, hermie.' '[]' 2984]
# ---
# 15
# ["Word's getting out you're a homo." "['homo']" 3303]
# ---
# ...
