# %%
import re
import numpy as np
import zipfile
import pandas as pd
import glob
import sys
import os

# %%
def srt_to_csv(movie_data, filename, destination):
    df = pd.DataFrame(movie_data, columns=['dialog'])
    print(df.head())
    print(df.columns)

    def cleansing(df, n, x):
        def remove_blank_lines(df):
            df.replace("", np.nan, inplace=True)
            df = df.dropna()
            return df

        def remove_brackets(df):
            df = df.replace(r'^-?\(.*\)$', '', regex=True)
            df = df.replace(r'\(.*?\)', '', regex=True)
            return df

        def strip_all_values(df):
            df = df.apply(lambda x: x.str.strip())
            return df

        def remove_specialchars(df):
            df = df.replace(r'[\=\-\{\}\[\]\^\#]', '', regex=True)
            df = df.replace(r'\\... ', '', regex=True)
            df = df.replace(r'<.*?>', '', regex=True)
            return df

        def remove_nonchar_lines(df):
            df = df.drop(df[df.dialog.str.contains(r'^\d?\d?\d?\d|\d\d:\d\d:\d\d,.*', regex=True)].index)
            return df

        def remove_first_n_lines(df, n):
            df = df.iloc[n:]
            return df

        df = remove_blank_lines(df)
        df = strip_all_values(df)
        df = remove_brackets(df)
        df = remove_nonchar_lines(df)
        df = remove_specialchars(df)
        df = remove_blank_lines(df)
        df = remove_first_n_lines(df, n)
        df = remove_blank_lines(df)

        return df


    df_movie = cleansing(df, 1, 0)

    movie_txt = df_movie.dialog.values.tolist()

    sent = ''
    new_l = []
    for t in movie_txt:
        if t[-1] not in ['.', '?', '!']:
            sent += t + ' '
        else:
            sent += t
            new_l.append(sent)
            sent = ''
    df_movie_updated = pd.DataFrame(columns=['dialog'])
    df_movie_updated['dialog'] = new_l
    df_movie_updated.head()

    print("converting to csv")
    df_movie_updated.to_csv(destination + filename[4:-4]+'.csv')

def main(path, destination):
    for filename in glob.glob(path+'*.srt'):
        print(filename)
        file_encoding = 'cp1252' 
        with open(filename, encoding=file_encoding, errors='replace') as f:
            lines = f.readlines()
        new_lines = srt_to_csv(lines, filename, destination)

# %%
path = 'SRT/'
destination = 'CSV/'
main(path, destination)
# Out:
# SRT\American History X (1998).DVDRip.NonHI.cc.en.NWLN.srt
#                             dialog
# 0                           ï»¿1\n
# 1  00:00:01,552 --> 00:00:04,419\n
# 2       CAPTIONING MADE POSSIBLE\n
# 3         BY NEW LINE HOME VIDEO\n
# 4                               \n
# Index(['dialog'], dtype='object')
# converting to csv
# SRT\BlacKkKlansman (2018)23.976fps-134.49 min mp4 version-syn-edited-colorized-moreCompleted-Hi.srt
#                                               dialog
# 0                                             ï»¿1\n
# 1                    00:00:43,657 --> 00:00:46,717\n
# 2      <font color=#ff00ff>- [MEN GROANING]</font>\n
# 3  <font color=#ff00ff>- [INDISTINCT CHATTER]</fo...
# 4                                                 \n
# Index(['dialog'], dtype='object')
# converting to csv
# SRT\Django.Unchained.2012.720p.BluRay.DTS.x264-HDMaNiAcS.srt
#                                        dialog
# 0                                      ï»¿1\n
# 1             00:04:18,937 --> 00:04:21,624\n
# 2  Who's that stumbling around in the dark?\n
# 3                                          \n
# 4                                         2\n
# Index(['dialog'], dtype='object')
# converting to csv
# SRT\Pulp.Fiction.1994.1080p.BluRay.EN.srt
#                             dialog
# 0                           ï»¿1\n
# 1  00:00:28,372 --> 00:00:32,500\n
# 2     Forget it. It's too risky.\n
# 3   I'm through doing that shit.\n
# 4                               \n
# Index(['dialog'], dtype='object')
# converting to csv
# SRT\South.Park.Bigger.Longer.and.Uncut.480p.BluRay.x264-MHQ.srt
#                             dialog
# 0                              1\n
# 1  00:00:31,776 --> 00:00:37,239\n
# 2       There's a bunch of birds\n
# 3                     in the sky\n
# 4                               \n
# Index(['dialog'], dtype='object')
# converting to csv
# SRT\The Wolf of Wall Street 2013 BluRay.srt
#                                              dialog
# 0                                            ï»¿1\n
# 1                   00:00:46,077 --> 00:00:49,956\n
# 2  <i>The world of investing can be a jungle.</i>\n
# 3                                                \n
# 4                                               2\n
# Index(['dialog'], dtype='object')
# converting to csv
